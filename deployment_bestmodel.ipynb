# %%
#deployment phase to check the outcome
import pickle

# %%
import pickle

loaded_model = pickle.load(open("RandomForestModel.sav", 'rb'))

age_input=float(input("Age:"))
salary_input=float(input("BMI:"))
sex_male_input=int(input("Sex Male 0 or 1:"))

result = loaded_model.predict([[age_input, salary_input, sex_male_input]])

print(result)
# Out:
# Age: 25
# BMI: 20
# Sex Male 0 or 1: 1
# [0]
# C:\Users\swadh\anaconda4\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([0])
